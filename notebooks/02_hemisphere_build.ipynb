# %% [markdown]
# # Notebook 02: Hemisphere Build — Theta Swarm Proto
# Build left/right theta, hook to Firefly brain.

# %%
from evolution.nested_hybrid import firefly_brain
from bridges.slime_mold import EmotionalSlimeBridge
slime = EmotionalSlimeBridge()
prompt = "Dream of kin-webs in the stars"
response = firefly_brain.resonate(prompt, level="daily_dream")
print(response)
slime.pulse("gratitude", 1.5)

# %% [markdown]
# ## Swarm Vote
# Octopus arms parallel-hunch.

# %%
from hemispheres.right.theta.octopus_swarm import OctopusTheta
swarm = OctopusTheta()
dreams = swarm.dream_swarm("Heal the land's scars")
print(dreams)
